# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [10, 15]
y = [20, 16]

plt.plot(x, y);

# %%
x = [10, 15]
y = [20, 16]

plt.scatter(x, y);

# %%
x = [10, 15, 30]
y = [20, 16, 40]

plt.scatter(x, y);

# %%
x = [10, 15, 30]
y = [20, 16, 40]

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.scatter(x, y);

# %%
x = [10, 15, 30]
y = [20, 16, 40]

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.array([10, 15, 30])
y = np.array([20, 16, 40])

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.array([10, 15, 30, 100])
y = np.array([20, 16, 40, 50])

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.array([10, 15, 30, 100])
y = np.array([20, 16, 40, 50])

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.bar(x, y);
# plt.plot(x, y);

# %%
x = np.array([10, 15, 30, 100])
y = np.array([20, 16, 40, 50])

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
plt.barh(x, y);
