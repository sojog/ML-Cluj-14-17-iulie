# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
result = make_regression()
type(result), len(result), type(result[0]), len(result[0]), type(result[1]), len(result[1])
# Out:
# (tuple, 2, numpy.ndarray, 100, numpy.ndarray, 100)

# %%
result = make_regression(n_samples=3)
type(result), len(result), type(result[0]), len(result[0]), type(result[1]), len(result[1])
# Out:
# (tuple, 2, numpy.ndarray, 3, numpy.ndarray, 3)

# %%
result = make_regression(n_samples=3, n_features=1)
type(result), len(result), type(result[0]), len(result[0]), type(result[1]), len(result[1])
result
# Out:
# (array([[-0.63488708],
#         [ 0.93037335],
#         [ 0.20067666]]),
#  array([-38.86036097,  56.94657397,  12.28307793]))

# %% [markdown]
# # X -> features (suprafete)
# # y -> target (preturi)

# %%
x, y = make_regression(n_samples=3, n_features=1)

# %%
x, x.shape
# Out:
# (array([[-0.01666816],
#         [-0.02271832],
#         [ 0.42641171]]),
#  (3, 1))

# %%
y, y.shape
# Out:
# (array([-0.57986724, -0.79034538, 14.83439744]), (3,))

# %% [markdown]
# # x - features (suprafata, anul_constructiei)

# %%
x, y = make_regression(n_samples=3, n_features=3)
x
# Out:
# array([[-0.31733188,  0.52273157,  0.8834943 ],
#        [ 1.03543582, -1.2138292 , -1.96312833],
#        [ 1.70515924,  0.87761773,  0.3175021 ]])

# %%
x, y = make_regression(n_samples=3, n_features=1)
plt.scatter(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1)
plt.scatter(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1)
plt.scatter(x, y);
plt.plot(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1)
plt.scatter(x, y);
plt.plot(x, y);

# %%
x, y = make_regression(n_samples=300, n_features=1)
plt.scatter(x, y);
plt.plot(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1, noise = 1)
plt.scatter(x, y);
plt.plot(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1, noise = 10)
plt.scatter(x, y);
# plt.plot(x, y);

# %%
x, y = make_regression(n_samples=30, n_features=1, noise = 100)
plt.scatter(x, y);
# plt.plot(x, y);

# %%
x, y = make_regression(n_samples=300, n_features=1, noise = 100)
plt.scatter(x, y);
