# %%
from sklearn.datasets import load_diabetes

# %%
diabetes_dataset = load_diabetes()
diabetes_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
x, y = load_diabetes(return_X_y=True)

# %%
# x - features
"samples:", x.shape[0], "featues", x.shape[1], y.shape
# Out:
# ('samples:', 442, 'featues', 10, (442,))

# %%
# y - target
y.min(), y.max()
# Out:
# (np.float64(25.0), np.float64(346.0))

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
std_scaler
# Out:
# StandardScaler()

# %%
x_scaled = std_scaler.fit_transform(x, y)
x_scaled.min(), x_scaled.max()
# Out:
# (np.float64(-2.896390054127642), np.float64(4.179278150080332))

# %%
x.min(), x.max()
# Out:
# (np.float64(-0.13776722569000302), np.float64(0.19878798965729408))

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline

std_scaler = StandardScaler()
knn_model = KNeighborsRegressor(n_neighbors=5)


pipeline_diabetes = Pipeline(
        [("scale", std_scaler),
        ("model", knn_model)]
    )
pipeline_diabetes
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', KNeighborsRegressor())])

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(pipeline_diabetes, param_grid= {
    "model__n_neighbors" : list(range(3, 7))
})

# %%
grid_model.fit(x, y)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('model', KNeighborsRegressor())]),
#              param_grid={'model__n_neighbors': [3, 4, 5, 6]})

# %%
grid_model.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', KNeighborsRegressor(n_neighbors=6))])

# %%
grid_model.best_score_
# Out:
# np.float64(0.384334024903244)
