# %% [markdown]
# # pip install pillow

# %%
import matplotlib.pylab as plt
from PIL import Image

# %%
Image.open("1_negru.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=8x8>

# %%
image = Image.open("1_negru.png").convert("L")
type(image)
# Out:
# PIL.Image.Image

# %%
type(image.resize((8, 8)))
# Out:
# PIL.Image.Image

# %%
plt.imshow(image)

# %%
plt.imshow(image, cmap="gray")
