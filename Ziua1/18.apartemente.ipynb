# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # mp vs pret

# %%
aparatamente = [(37, 65), (44, 70), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400)]

suprafete = list(map(lambda x:x[0], aparatamente))
suprafete


preturi = [ i[1] for i in aparatamente ]
preturi
# Out:
# [65, 70, 80, 120, 95, 205, 75, 400]

# %%
plt.scatter(suprafete, preturi)

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)

# %%
aparatamente = np.array([(37, 65), (44, 70), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400)])

preturi = aparatamente[1, 0]
preturi
# Out:
# np.int64(44)

# %%
aparatamente = np.array([(37, 65), (44, 70), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400)])
aparatamente = aparatamente[aparatamente[:, 0].argsort()]
print("aparatamente=", aparatamente)


suprafete = aparatamente[ : , 0]
suprafete

preturi = aparatamente[ : , 1]
preturi
# Out:
# aparatamente= [[ 37  65]
#  [ 41  75]
#  [ 44  70]
#  [ 55  80]
#  [ 60  95]
#  [ 80 120]
#  [ 92 205]
#  [170 400]]
# array([ 65,  75,  70,  80,  95, 120, 205, 400])

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)

# %%
print(suprafete)

def f(x):
    a = 0
    b = 50
    return a * x + b

preturi_generate = list(map(f, suprafete))

plt.plot(suprafete, preturi_generate, c="red")

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
# Out:
# [ 37  41  44  55  60  80  92 170]

# %%
print(suprafete)

def f(x):
    a = 1.7
    b = 50
    return a * x + b

preturi_generate = list(map(f, suprafete))

plt.plot(suprafete, preturi_generate, c="red")

plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)
# Out:
# [ 37  41  44  55  60  80  92 170]

# %%
f(120)
# Out:
# 254.0

# %%
print(suprafete)

def f1(x):
    a = 1.7
    b = 50
    return a * x + b

preturi_generate1 = list(map(f1, suprafete))
plt.plot(suprafete, preturi_generate1, c="red")


def f2(x):
    a = 2
    b = 0
    return a * x + b

preturi_generate2 = list(map(f2, suprafete))
plt.plot(suprafete, preturi_generate2, c="green")


plt.scatter(suprafete, preturi)
# plt.plot(suprafete, preturi)
# Out:
# [ 37  41  44  55  60  80  92 170]

# %%
x_array = np.arange(10)
y_array =np.arange(10)

print(y_array[3])
y_array[3] = 4

plt.plot(x_array, y_array)
plt.scatter(x_array, y_array)
# Out:
# 3

# %%
print(suprafete)

def f1(x):
    a = 1.7
    b = 50
    return a * x + b

preturi_generate1 = list(map(f1, suprafete))
plt.plot(suprafete, preturi_generate1, c="red")


def f2(x):
    a = 2
    b = 0
    return a * x + b

preturi_generate2 = list(map(f2, suprafete))
plt.plot(suprafete, preturi_generate2, c="green")




plt.scatter(suprafete, preturi)

# %%
from scipy import stats
rezultat =  stats.linregress(suprafete, preturi)
print(rezultat.slope, rezultat.intercept)
# Out:
# 2.5823365101754843 -48.14660492395066

# %%
print(suprafete)

def f1(x):
    a = 1.7
    b = 50
    return a * x + b

preturi_generate1 = list(map(f1, suprafete))
plt.plot(suprafete, preturi_generate1, c="red")


def f2(x):
    a = 2
    b = 0
    return a * x + b

preturi_generate2 = list(map(f2, suprafete))
plt.plot(suprafete, preturi_generate2, c="green")

def f_optim(x):
    a = 2.5823365101754843
    b = -48.14660492395066
    return a * x + b


preturi_generate_optim = list(map(f_optim, suprafete))
plt.plot(suprafete, preturi_generate_optim, c="black")



plt.scatter(suprafete, preturi)
# Out:
# [ 37  41  44  55  60  80  92 170]

# %%
f_optim(40)
# Out:
# 55.146855483068705
